# %%
from ultralytics import YOLO

# 모델 로드
model = YOLO("yolov8n.pt")

# 이미지 추론
results = model("5. 단풍.jpg")
# 결과 가져오기
result = results[0]

# 박스 정보
boxes = result.boxes
names = result.names

# 좌표 출력
for box in boxes:
    # 좌표 (xmin, ymin, xmax, ymax)
    x1, y1, x2, y2 = box.xyxy[0].tolist()

    # confidence score
    conf = box.conf[0].item()

    # 클래스 id
    cls = int(box.cls[0].item())

    label = names[cls]
    print(f"{label} ({conf:.2f})")
    print(f"bbox: ({x1:.1f}, {y1:.1f}, {x2:.1f}, {y2:.1f})")
# 결과 출력
import matplotlib.pyplot as plt

img = result.plot()
plt.imshow(img)
plt.axis('off')
plt.show()
# Out:
# image 1/1 c:\Users\safi2\Documents\GitHub\sci-snap\LM\8.  .jpg: 352x640 16 persons, 2 cars, 3 umbrellas, 1 frisbee, 36.7ms
# Speed: 1.2ms preprocess, 36.7ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
# car (0.82)
# bbox: (0.0, 83.0, 67.4, 207.5)
# person (0.69)
# bbox: (626.1, 105.0, 679.1, 219.6)
# car (0.67)
# bbox: (475.9, 126.2, 587.6, 216.9)
# person (0.66)
# bbox: (56.7, 112.7, 108.8, 220.0)
# person (0.63)
# bbox: (681.1, 117.4, 715.2, 220.9)
# person (0.63)
# bbox: (102.0, 105.6, 154.0, 218.7)
# person (0.63)
# bbox: (375.1, 112.1, 408.9, 220.3)
# person (0.60)
# bbox: (168.3, 107.7, 214.2, 217.3)
# person (0.55)
# bbox: (161.7, 105.3, 190.9, 206.2)
# person (0.53)
# bbox: (433.1, 99.9, 480.7, 216.2)
# umbrella (0.53)
# bbox: (265.9, 86.8, 338.7, 116.5)
# umbrella (0.51)
# bbox: (165.3, 93.0, 225.3, 126.8)
# person (0.48)
# bbox: (295.5, 115.4, 335.5, 224.2)
# person (0.44)
# bbox: (141.3, 103.3, 168.9, 207.4)
# person (0.43)
# bbox: (331.7, 107.4, 357.4, 213.2)
# person (0.43)
# bbox: (346.7, 110.5, 386.3, 227.3)
# person (0.43)
# bbox: (231.0, 106.6, 274.6, 217.5)
# umbrella (0.42)
# bbox: (332.4, 89.6, 394.0, 119.1)
# person (0.36)
# bbox: (278.8, 115.8, 305.8, 217.2)
# person (0.34)
# bbox: (602.0, 110.0, 638.5, 219.5)
# frisbee (0.29)
# bbox: (590.7, 78.1, 640.5, 120.1)
# person (0.27)
# bbox: (264.1, 110.1, 287.1, 210.3)

# %%
# 좌표 list

labels = [names[int(box.cls.item())] for box in boxes]
confs = [box.conf.item() for box in boxes]

# 클래스 id
cls = int(box.cls.item())

label = names[cls]

print(f"{labels}")
print(f"bbox: {boxes.xyxy.tolist()}")
# Out:
# ['car', 'person', 'car', 'person', 'person', 'person', 'person', 'person', 'person', 'person', 'umbrella', 'umbrella', 'person', 'person', 'person', 'person', 'person', 'umbrella', 'person', 'person', 'frisbee', 'person']
# bbox: [[0.0, 82.98116302490234, 67.41950988769531, 207.5082244873047], [626.0850219726562, 105.03125762939453, 679.1250610351562, 219.5980224609375], [475.8988037109375, 126.20548248291016, 587.5949096679688, 216.9219207763672], [56.653812408447266, 112.74503326416016, 108.82209014892578, 220.0352325439453], [681.0502319335938, 117.41322326660156, 715.1641845703125, 220.9080810546875], [101.98800659179688, 105.63980102539062, 153.9658966064453, 218.73095703125], [375.05926513671875, 112.06302642822266, 408.8602294921875, 220.34068298339844], [168.29066467285156, 107.74284362792969, 214.1636962890625, 217.34603881835938], [161.6986846923828, 105.2923583984375, 190.89381408691406, 206.20460510253906], [433.1339111328125, 99.85829162597656, 480.7414245605469, 216.19692993164062], [265.9001159667969, 86.77884674072266, 338.72747802734375, 116.53058624267578], [165.27670288085938, 92.95089721679688, 225.27540588378906, 126.83483123779297], [295.5081787109375, 115.39718627929688, 335.45806884765625, 224.16854858398438], [141.3350830078125, 103.30232238769531, 168.91189575195312, 207.37242126464844], [331.6942443847656, 107.39765167236328, 357.3590087890625, 213.2450408935547], [346.6985168457031, 110.52619934082031, 386.32269287109375, 227.30384826660156], [231.03424072265625, 106.56653594970703, 274.5918884277344, 217.50930786132812], [332.4376525878906, 89.5556411743164, 394.03900146484375, 119.12427520751953], [278.8457946777344, 115.77393341064453, 305.7669677734375, 217.21389770507812], [601.968505859375, 109.95307922363281, 638.5294799804688, 219.4841766357422], [590.6791381835938, 78.05814361572266, 640.52978515625, 120.12731170654297], [264.05426025390625, 110.10452270507812, 287.09942626953125, 210.3460235595703]]
