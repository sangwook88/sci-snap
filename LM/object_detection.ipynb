# %%
from ultralytics import YOLO

# 모델 로드
model = YOLO("yolov8n.pt")

# 이미지 추론
results = model("8. 아지랑이 현상.jpg")
# 결과 가져오기
result = results[0]

# 박스 정보
boxes = result.boxes
names = result.names

# 좌표 출력
for box in boxes:
    # 좌표 (xmin, ymin, xmax, ymax)
    x1, y1, x2, y2 = box.xyxy[0].tolist()

    # confidence score
    conf = box.conf[0].item()

    # 클래스 id
    cls = int(box.cls[0].item())

    label = names[cls]
    print(f"{label} ({conf:.2f})")
    print(f"bbox: ({x1:.1f}, {y1:.1f}, {x2:.1f}, {y2:.1f})")
# 결과 출력
import matplotlib.pyplot as plt

img = result.plot()
plt.imshow(img)
plt.axis('off')
plt.show()
# Out:
# image 1/1 /home/saul_park/workspace/code/others/sci-snap/LM/8. 아지랑이 현상.jpg: 352x640 16 persons, 2 cars, 3 umbrellas, 1 frisbee, 143.4ms
# Speed: 5.1ms preprocess, 143.4ms inference, 36.3ms postprocess per image at shape (1, 3, 352, 640)
# car (0.82)
# bbox: (0.0, 83.0, 67.4, 207.5)
# person (0.69)
# bbox: (626.1, 105.0, 679.1, 219.6)
# car (0.67)
# bbox: (475.9, 126.2, 587.6, 216.9)
# person (0.66)
# bbox: (56.7, 112.7, 108.8, 220.0)
# person (0.63)
# bbox: (681.1, 117.4, 715.2, 220.9)
# person (0.63)
# bbox: (102.0, 105.6, 154.0, 218.7)
# person (0.63)
# bbox: (375.1, 112.1, 408.9, 220.3)
# person (0.60)
# bbox: (168.3, 107.7, 214.2, 217.3)
# person (0.55)
# bbox: (161.7, 105.3, 190.9, 206.2)
# person (0.53)
# bbox: (433.1, 99.9, 480.7, 216.2)
# umbrella (0.53)
# bbox: (265.9, 86.8, 338.7, 116.5)
# umbrella (0.51)
# bbox: (165.3, 93.0, 225.3, 126.8)
# person (0.48)
# bbox: (295.5, 115.4, 335.5, 224.2)
# person (0.44)
# bbox: (141.3, 103.3, 168.9, 207.4)
# person (0.43)
# bbox: (331.7, 107.4, 357.4, 213.2)
# person (0.43)
# bbox: (346.7, 110.5, 386.3, 227.3)
# person (0.43)
# bbox: (231.0, 106.7, 273.5, 217.0)
# umbrella (0.42)
# bbox: (332.4, 89.6, 394.1, 119.1)
# person (0.36)
# bbox: (278.8, 115.8, 305.8, 217.2)
# person (0.34)
# bbox: (602.0, 110.0, 638.5, 219.5)
# frisbee (0.29)
# bbox: (590.7, 78.1, 640.5, 120.1)
# person (0.27)
# bbox: (264.0, 110.1, 287.1, 210.4)

# %%
# 좌표 list

labels = [names[int(box.cls.item())] for box in boxes]
confs = [box.conf.item() for box in boxes]

# 클래스 id
cls = int(box.cls.item())

label = names[cls]

print(f"{labels}")
print(f"bbox: {boxes.xyxy.tolist()}")
# Out:
# ['car', 'person', 'car', 'person', 'person', 'person', 'person', 'person', 'person', 'person', 'umbrella', 'umbrella', 'person', 'person', 'person', 'person', 'person', 'umbrella', 'person', 'person', 'frisbee', 'person']
# bbox: [[0.0, 82.97462463378906, 67.4197998046875, 207.501220703125], [626.0880126953125, 105.03783416748047, 679.1300048828125, 219.59510803222656], [475.89801025390625, 126.20407104492188, 587.6006469726562, 216.92222595214844], [56.663970947265625, 112.74931335449219, 108.82170104980469, 220.0332794189453], [681.0537719726562, 117.41082000732422, 715.1681518554688, 220.9075164794922], [101.98690795898438, 105.63726806640625, 153.9696044921875, 218.73060607910156], [375.0565185546875, 112.06254577636719, 408.86328125, 220.34033203125], [168.29196166992188, 107.74482727050781, 214.1651611328125, 217.34707641601562], [161.69960021972656, 105.29104614257812, 190.8936309814453, 206.20970153808594], [433.13665771484375, 99.85519409179688, 480.74224853515625, 216.199951171875], [265.89703369140625, 86.77848815917969, 338.7436218261719, 116.53053283691406], [165.2947235107422, 92.95269012451172, 225.28160095214844, 126.83216094970703], [295.50732421875, 115.39783477783203, 335.46832275390625, 224.1673583984375], [141.33535766601562, 103.30689239501953, 168.9134979248047, 207.36907958984375], [331.6960144042969, 107.4009017944336, 357.3619079589844, 213.2366180419922], [346.697998046875, 110.53009033203125, 386.3200378417969, 227.30056762695312], [231.00677490234375, 106.72492980957031, 273.49481201171875, 217.03533935546875], [332.4361572265625, 89.55499267578125, 394.0506591796875, 119.12522888183594], [278.8467102050781, 115.77677917480469, 305.7705383300781, 217.22027587890625], [601.966796875, 109.9563980102539, 638.5370483398438, 219.4799041748047], [590.6788330078125, 78.05767059326172, 640.5311279296875, 120.1278305053711], [264.0491943359375, 110.0998306274414, 287.10528564453125, 210.35342407226562]]
